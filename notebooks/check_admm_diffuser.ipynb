# %% [markdown]
# # Matrix retrieval attempt using ADMM

# %% [markdown]
# ## Load packages

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
from pr.admm import admm_pr
from tmr.tmr import TMR

# %% [markdown]
# ## Import old measurement data

# %%
data = loadmat('imports/diffuser/matMeas.mat') # Contains A and B keys: A = input phases, B = output intensities
result = loadmat('imports/diffuser/X_16f_64d_20N.mat') # Contains XkNorm key, the old retrieved transfer matrix

A = data['A']
B = data['B']
A = A[1:-1,:]
B = B[1:-1,:]
A = np.exp(1j * A)
B = np.sqrt(B)
X = result['XkNorm']

# %% [markdown]
# ## Retrieve matrices using current implementation

# %%
tmr = TMR(A, B, verbose=False, device='cuda')
tmr.run_admm(max_iter=100, lr=1e-2, tol=1e-7, rho=1)
tmr.show_results()

# %% [markdown]
# ## Phase retrieval attempt using ADMM and the transfer matrix recovered using ADMM

# %%
tm = tmr.X_best.T
x0 = np.random.randn(A.shape[1],1) + 1j * np.random.randn(A.shape[1],1)
b = np.abs(np.dot(tm, x0))
b = b / np.max(b)
b = np.sqrt( np.abs(np.square(b) + 0.05*np.random.rand(b.shape[0])))


x = admm_pr(tm, b, rho=1, max_iter=100, max_inner_iter=100, tol=1e-7, lr=1e-2, verbose=1, device='cuda')
x = x.cpu().detach().numpy()

fig, axs = plt.subplots(1, 2, figsize=(15,4))
axs[0].plot(np.abs(x0), label='Initial')
axs[0].plot(np.abs(x), label='Retrieved')
axs[0].set_title('Vectors magnitudes')
axs[0].legend()

axs[1].plot(np.angle(np.exp(1j * (np.angle(x0)-np.angle(x0[0])))), label='Initial')
axs[1].plot(np.angle(np.exp(1j * (np.angle(x)-np.angle(x[0])))), label='Retrieved')
axs[1].set_title('Vectors angles')
axs[1].legend()
# Out:
# Iteration:   1 - distance = 2.980e+01 - stopping distance = 7.419e+01
# Iteration:   2 - distance = 2.972e-01 - stopping distance = 2.951e+01
# Iteration:   3 - distance = 2.231e-01 - stopping distance = 7.416e-02
# Iteration:   4 - distance = 2.247e-01 - stopping distance = 1.643e-03
# Iteration:   5 - distance = 2.260e-01 - stopping distance = 1.266e-03
# Iteration:   6 - distance = 2.217e-01 - stopping distance = 4.295e-03
# Iteration:   7 - distance = 2.232e-01 - stopping distance = 1.530e-03
# Iteration:   8 - distance = 2.242e-01 - stopping distance = 9.958e-04
# Iteration:   9 - distance = 2.247e-01 - stopping distance = 5.268e-04
# Iteration:  10 - distance = 2.239e-01 - stopping distance = 8.127e-04
# Iteration:  11 - distance = 2.267e-01 - stopping distance = 2.744e-03
# Iteration:  12 - distance = 2.265e-01 - stopping distance = 2.047e-04
# Iteration:  13 - distance = 2.288e-01 - stopping distance = 2.331e-03
# Iteration:  14 - distance = 2.272e-01 - stopping distance = 1.566e-03
# Iteration:  15 - distance = 2.267e-01 - stopping distance = 5.710e-04
# Iteration:  16 - distance = 2.252e-01 - stopping distance = 1.489e-03
# Iteration:  17 - distance = 2.268e-01 - stopping distance = 1.616e-03
# Iteration:  18 - distance = 2.279e-01 - stopping distance = 1.105e-03
# Iteration:  19 - distance = 2.290e-01 - stopping distance = 1.156e-03
# Iteration:  20 - distance = 2.270e-01 - stopping distance = 2.000e-03
# Iteration:  21 - distance = 2.280e-01 - stopping distance = 9.647e-04
# Iteration:  22 - distance = 2.264e-01 - stopping distance = 1.597e-03
# Iteration:  23 - distance = 2.289e-01 - stopping distance = 2.496e-03
# Iteration:  24 - distance = 2.269e-01 - stopping distance = 1.965e-03
# Iteration:  25 - distance = 2.279e-01 - stopping distance = 9.249e-04
# Iteration:  26 - distance = 2.283e-01 - stopping distance = 4.200e-04
# Iteration:  27 - distance = 2.252e-01 - stopping distance = 3.054e-03
# Iteration:  28 - distance = 2.275e-01 - stopping distance = 2.283e-03
# Iteration:  29 - distance = 2.269e-01 - stopping distance = 6.294e-04
# Iteration:  30 - distance = 2.279e-01 - stopping distance = 1.053e-03
# Iteration:  31 - distance = 2.260e-01 - stopping distance = 1.970e-03
# Iteration:  32 - distance = 2.271e-01 - stopping distance = 1.173e-03
# Iteration:  33 - distance = 2.270e-01 - stopping distance = 1.599e-04
# Iteration:  34 - distance = 2.265e-01 - stopping distance = 4.925e-04
# Iteration:  35 - distance = 2.279e-01 - stopping distance = 1.413e-03
# Iteration:  36 - distance = 2.276e-01 - stopping distance = 3.469e-04
# Iteration:  37 - distance = 2.273e-01 - stopping distance = 2.860e-04
# Iteration:  38 - distance = 2.253e-01 - stopping distance = 1.968e-03
# Iteration:  39 - distance = 2.265e-01 - stopping distance = 1.208e-03
# Iteration:  40 - distance = 2.256e-01 - stopping distance = 9.478e-04
# Iteration:  41 - distance = 2.324e-01 - stopping distance = 6.871e-03
# Iteration:  42 - distance = 2.264e-01 - stopping distance = 6.005e-03
# Iteration:  43 - distance = 2.275e-01 - stopping distance = 1.022e-03
# Iteration:  44 - distance = 2.267e-01 - stopping distance = 7.441e-04
# Iteration:  45 - distance = 2.283e-01 - stopping distance = 1.634e-03
# Iteration:  46 - distance = 2.286e-01 - stopping distance = 3.032e-04
# Iteration:  47 - distance = 2.271e-01 - stopping distance = 1.583e-03
# Iteration:  48 - distance = 2.277e-01 - stopping distance = 6.048e-04
# Iteration:  49 - distance = 2.294e-01 - stopping distance = 1.703e-03
# Iteration:  50 - distance = 2.265e-01 - stopping distance = 2.835e-03
# Iteration:  51 - distance = 2.274e-01 - stopping distance = 8.592e-04
# Iteration:  52 - distance = 2.260e-01 - stopping distance = 1.418e-03
# Iteration:  53 - distance = 2.255e-01 - stopping distance = 4.992e-04
# Iteration:  54 - distance = 2.261e-01 - stopping distance = 5.896e-04
# Iteration:  55 - distance = 2.270e-01 - stopping distance = 9.511e-04
# Iteration:  56 - distance = 2.258e-01 - stopping distance = 1.183e-03
# Iteration:  57 - distance = 2.249e-01 - stopping distance = 9.222e-04
# Iteration:  58 - distance = 2.264e-01 - stopping distance = 1.489e-03
# Iteration:  59 - distance = 2.289e-01 - stopping distance = 2.516e-03
# Iteration:  60 - distance = 2.262e-01 - stopping distance = 2.739e-03
# Iteration:  61 - distance = 2.285e-01 - stopping distance = 2.298e-03
# Iteration:  62 - distance = 2.301e-01 - stopping distance = 1.648e-03
# Iteration:  63 - distance = 2.299e-01 - stopping distance = 2.728e-04
# Iteration:  64 - distance = 2.269e-01 - stopping distance = 2.934e-03
# Iteration:  65 - distance = 2.257e-01 - stopping distance = 1.186e-03
# Iteration:  66 - distance = 2.263e-01 - stopping distance = 5.813e-04
# Iteration:  67 - distance = 2.279e-01 - stopping distance = 1.595e-03
# Iteration:  68 - distance = 2.272e-01 - stopping distance = 7.442e-04
# Iteration:  69 - distance = 2.296e-01 - stopping distance = 2.441e-03
# Iteration:  70 - distance = 2.248e-01 - stopping distance = 4.826e-03
# Iteration:  71 - distance = 2.274e-01 - stopping distance = 2.591e-03
# Iteration:  72 - distance = 2.238e-01 - stopping distance = 3.581e-03
# Iteration:  73 - distance = 2.243e-01 - stopping distance = 5.499e-04
# Iteration:  74 - distance = 2.250e-01 - stopping distance = 6.275e-04
# Iteration:  75 - distance = 2.305e-01 - stopping distance = 5.516e-03
# Iteration:  76 - distance = 2.278e-01 - stopping distance = 2.682e-03
# Iteration:  77 - distance = 2.284e-01 - stopping distance = 6.192e-04
# Iteration:  78 - distance = 2.246e-01 - stopping distance = 3.841e-03
# Iteration:  79 - distance = 2.312e-01 - stopping distance = 6.626e-03
# Iteration:  80 - distance = 2.254e-01 - stopping distance = 5.840e-03
# Iteration:  81 - distance = 2.244e-01 - stopping distance = 9.647e-04
# Iteration:  82 - distance = 2.253e-01 - stopping distance = 8.603e-04
# Iteration:  83 - distance = 2.281e-01 - stopping distance = 2.888e-03
# Iteration:  84 - distance = 2.342e-01 - stopping distance = 6.084e-03
# Iteration:  85 - distance = 2.289e-01 - stopping distance = 5.325e-03
# Iteration:  86 - distance = 2.277e-01 - stopping distance = 1.243e-03
# Iteration:  87 - distance = 2.284e-01 - stopping distance = 7.802e-04
# Iteration:  88 - distance = 2.265e-01 - stopping distance = 1.994e-03
# Iteration:  89 - distance = 2.272e-01 - stopping distance = 7.397e-04
# Iteration:  90 - distance = 2.278e-01 - stopping distance = 6.402e-04
# Iteration:  91 - distance = 2.271e-01 - stopping distance = 6.980e-04
# Iteration:  92 - distance = 2.264e-01 - stopping distance = 6.845e-04
# Iteration:  93 - distance = 2.279e-01 - stopping distance = 1.436e-03
# Iteration:  94 - distance = 2.274e-01 - stopping distance = 4.414e-04
# Iteration:  95 - distance = 2.271e-01 - stopping distance = 3.325e-04
# Iteration:  96 - distance = 2.298e-01 - stopping distance = 2.669e-03
# Iteration:  97 - distance = 2.282e-01 - stopping distance = 1.591e-03
# Iteration:  98 - distance = 2.289e-01 - stopping distance = 6.822e-04
# Iteration:  99 - distance = 2.288e-01 - stopping distance = 1.030e-04

# %% [markdown]
# ## Compare estimated matrices with the old one

# %%
titles = [r"$|X_{orig}|$", r"$|X_{est}|$", r"$\angle X_{orig}$", r"$\angle X_{est}$"]
pls = []

fig, axs = plt.subplots(1, 4, figsize=(12,4))
pls.append(axs[0].imshow(np.abs(X), cmap="hot"))
pls.append(axs[1].imshow(np.abs(tmr.X_norm.T), cmap="hot"))
pls.append(axs[2].imshow(np.angle(X), cmap="twilight"))
pls.append(axs[3].imshow(np.angle(tmr.X_norm.T), cmap="twilight"))
[ plt.colorbar(pls[i], ax=axs[i]) for i in range(len(pls)) ]
[ axs[i].set_title(titles[i]) for i in range(len(pls)) ]
[ axs[i].axis('off') for i in range(len(pls)) ]
# Out:
# [(-0.5, 15.5, 63.5, -0.5),
#  (-0.5, 15.5, 63.5, -0.5),
#  (-0.5, 15.5, 63.5, -0.5),
#  (-0.5, 15.5, 63.5, -0.5)]

# %%
titles = [r"$|X_{est}| - |X_{orig}|$", r"$\angle X_{est} - \angle X_{orig}$"]
pls = []

fig, axs = plt.subplots(1, 2, figsize=(7,4))
pls.append(axs[0].imshow(np.abs(tmr.X_norm.T) - np.abs(X), cmap="bwr"))
pls.append(axs[1].imshow(np.angle(np.exp(1j * (np.angle(tmr.X_norm.T) - np.angle(X)))), cmap="twilight"))
[ plt.colorbar(pls[i], ax=axs[i]) for i in range(len(pls)) ]
[ axs[i].set_title(titles[i]) for i in range(len(pls)) ]
[ axs[i].axis('off') for i in range(len(pls)) ]
# Out:
# [(-0.5, 15.5, 63.5, -0.5), (-0.5, 15.5, 63.5, -0.5)]

# %% [markdown]
# # Compare outputs from retrieved matrices with measured outputs

# %%
B_X = np.abs(np.dot(A, X.T))
B_X1 = np.abs(np.dot(A, tmr.X_norm))

titles = [r"$B_{dset}$", r"$B_{X_{orig}}$", r"$B_{X_{est}}$"]
pls = []

fig, axs = plt.subplots(1, 3, figsize=(9,4))
pls.append(axs[0].imshow(B / np.max(B), cmap="hot"))
pls.append(axs[1].imshow(B_X / np.max(B_X), cmap="hot"))
pls.append(axs[2].imshow(B_X1 / np.max(B_X1), cmap="hot"))
[ plt.colorbar(pls[i], ax=axs[i]) for i in range(len(pls)) ]
[ axs[i].set_title(titles[i]) for i in range(len(pls)) ]
[ axs[i].axis('off') for i in range(len(pls)) ]
# Out:
# [(-0.5, 63.5, 349.5, -0.5),
#  (-0.5, 63.5, 349.5, -0.5),
#  (-0.5, 63.5, 349.5, -0.5)]

# %%
titles = [r"$B_{X_{orig}} - B_{dset}$", r"$B_{X_{est}} - B_{dset}$"]
pls = []

fig, axs = plt.subplots(1, 2, figsize=(12,4))
pls.append(axs[0].imshow(B_X / np.max(B_X) - B / np.max(B), cmap="bwr"))
pls.append(axs[1].imshow(B_X1 / np.max(B_X1) - B / np.max(B), cmap="bwr"))
[ plt.colorbar(pls[i], ax=axs[i]) for i in range(len(pls)) ]
[ axs[i].set_title(titles[i]) for i in range(len(pls)) ]
[ axs[i].axis('off') for i in range(len(pls)) ]


titles = [r"$B_{X_{orig}} - B_{dset}$", r"$B_{X_{est}} - B_{dset}$"]
pls = []

mse_B_X = np.mean(np.abs(B_X / np.max(B_X) - B / np.max(B)), axis=0)
mse_B_X1 = np.mean(np.abs(B_X1 / np.max(B_X1) - B / np.max(B)), axis=0)

fig = plt.figure(figsize=(12,4))
plt.plot(mse_B_X, label=r"$MSE(B_{X_{orig}}, B_{dset})$")
plt.plot(mse_B_X1, label=r"$MSE(B_{X_{est}}, B_{dset})$")
plt.legend()

# %% [markdown]
# ## Compare inverted matrices and resulting phase maps

# %%
X_pinv = np.linalg.pinv(X.T)
X1_pinv = np.linalg.pinv(tmr.X_norm)

A_X = np.dot(B_X, X_pinv)
A_X1 = np.dot(B_X1, X1_pinv)

A_X = A_X / np.max(np.abs(A_X))
A_X1 = A_X1 / np.max(np.abs(A_X1))

titles = [r"$|A_{dset}|$", r"$|A_{X_{orig}}|$", r"$|A_{X_{est}}|$",
          r"$\angle A_{dset}$", r"$\angle A_{X_{orig}}$", r"$\angle A_{X_{est}}$"]
pls = []

fig, axs = plt.subplots(6, 1, figsize=(9,12))
pls.append(axs[0].imshow(np.abs(A.T), cmap="hot"))
pls.append(axs[1].imshow(np.abs(A_X.T), cmap="hot"))
pls.append(axs[2].imshow(np.abs(A_X1.T), cmap="hot"))
pls.append(axs[3].imshow(np.angle(A.T), cmap="twilight"))
pls.append(axs[4].imshow(np.angle(A_X.T), cmap="twilight"))
pls.append(axs[5].imshow(np.angle(A_X1.T), cmap="twilight"))
[ plt.colorbar(pls[i], ax=axs[i]) for i in range(len(pls)) ]
[ axs[i].set_title(titles[i]) for i in range(len(pls)) ]
[ axs[i].axis('off') for i in range(len(pls)) ]
# Out:
# [(-0.5, 349.5, 15.5, -0.5),
#  (-0.5, 349.5, 15.5, -0.5),
#  (-0.5, 349.5, 15.5, -0.5),
#  (-0.5, 349.5, 15.5, -0.5),
#  (-0.5, 349.5, 15.5, -0.5),
#  (-0.5, 349.5, 15.5, -0.5)]

# %%
titles = [r"$|A_{X_{orig}}| - |A_{dset}|$", r"$|A_{X_{est}}| - |A_{dset}|$",
          r"$\angle A_{X_{orig}} - \angle A_{dset}$", r"$\angle A_{X_{est}} - \angle A_{dset}$"]
pls = []

fig, axs = plt.subplots(4, 1, figsize=(12,12))
pls.append(axs[0].imshow(np.abs(A_X.T) - np.abs(A.T), cmap="bwr"))
pls.append(axs[1].imshow(np.abs(A_X1.T) - np.abs(A.T), cmap="bwr"))
pls.append(axs[2].imshow(np.angle(np.exp(1j * (np.angle(A_X.T) - np.angle(A.T)))), cmap="twilight"))
pls.append(axs[3].imshow(np.angle(np.exp(1j * (np.angle(A_X1.T) - np.angle(A.T)))), cmap="twilight"))
[ plt.colorbar(pls[i], ax=axs[i]) for i in range(len(pls)) ]
[ axs[i].set_title(titles[i]) for i in range(len(pls)) ]
[ axs[i].axis('off') for i in range(len(pls)) ]
# Out:
# [(-0.5, 349.5, 15.5, -0.5),
#  (-0.5, 349.5, 15.5, -0.5),
#  (-0.5, 349.5, 15.5, -0.5),
#  (-0.5, 349.5, 15.5, -0.5)]

# %% [markdown]
# ## Compare outputs from inverted phases
#
# Do it for only one case (randomly drawn from the dataset) for easier readability

# %%
idx = np.random.randint(0, A.shape[0])

a = A[idx, :]
a_X = A_X[idx, :]
a_X1 = A_X1[idx, :]


b = B[idx, :]
b_X = np.abs(np.dot(X, a_X))
b_X1 = np.abs(np.dot(X, a_X1))


fig, axs = plt.subplots(1, 2, figsize=(12,4))
axs[0].plot(np.abs(a), label=r"$|a_{dset}|$")
axs[0].plot(np.abs(a_X), label=r"$|a_{X_{orig}}|$")
axs[0].plot(np.abs(a_X1), label=r"$|a_{X_{est}}|$")
axs[1].plot(np.angle(np.exp(1j * (a - a[0]))), label=r"$\angle a_{dset}$")
axs[1].plot(np.angle(np.exp(1j * (np.angle(a_X) - np.angle(a_X[0])))), label=r"$\angle a_{X_{orig}}$")
axs[1].plot(np.angle(np.exp(1j * (np.angle(a_X1) - np.angle(a_X1[0])))), label=r"$\angle a_{X_{est}}$")
axs[0].set_title('Amplitudes of inputs')
axs[1].set_title('Phases of inputs')
axs[0].legend()
axs[1].legend()


fig = plt.figure(figsize=(12,4))
ax = plt.gca()
ax.plot(np.abs(b) / np.max(b), label=r"$|b_{dset}|$")
ax.plot(np.abs(b_X) / np.max(b_X), label=r"$|b_{X_{orig}}|$")
ax.plot(np.abs(b_X1) / np.max(b_X1), label=r"$|b_{X_{est}}|$")
ax.set_title('Amplitudes of outputs')
ax.legend()
