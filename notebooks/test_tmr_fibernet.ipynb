# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import tmr.pim_tmr as pim
import utils.matrices as pim_mats
import fibernet
import torch
from tmr.tmr import TMR
import matplotlib.pyplot as plt

from tmr.pim_tmr import wirtinger_initialization
from utils.utils import get_subsets, select_pixels, crop_img

import mat73
import os
from scipy.io import loadmat

# %%
path = "C:\\Users\\saucourt\\Datasets"
file = "data_base_02_03_0deg.mat"
data = mat73.loadmat(os.path.join(path, file))
# data = loadmat(os.path.join(path, file))

CP = np.reshape(np.array(data['CP']), newshape=(-1, 128, 128))
vec = np.reshape(np.array(data['vecteur_36']) , newshape=(-1, 36))

# %%
NN = CP.shape[0]
As = np.zeros(shape=(NN, 32), dtype=complex)
Bs = np.zeros(shape=(NN, 122*122), dtype=float)

amp = fibernet.dataset._utils.make_bellshaped_plane_2d(vec[0].reshape((6,6)))
amp = amp.flatten()

idxs = np.arange(4, 122, 128/30).astype(int)
print(idxs.shape)
Bs = np.zeros(shape=(NN, len(idxs)**2), dtype=float)

for i in range(NN):
    phi = vec[i]
    phi = amp * np.exp(1j * phi)
    phi = np.exp(1j * phi)
    phi = np.delete(vec[i], [0, 5, 30, 35])
    img = crop_img(CP[i], crop=3)
    img = select_pixels(img, idxs)
    img = img.flatten().astype('float')
    As[i,:] = phi
    Bs[i,:] = np.sqrt(img)
# Out:
# (28,)

# %%
torch.cuda.empty_cache()
As_crop, Bs_crop = get_subsets(As, Bs, N=51, randomize=True)

# Tolerance criterion has to be adjusted to be realistic and ensure the convergence
# init = wirtinger_initialization(As_crop, Bs_crop)
# X_est = pim.pim_tmr(As_crop, Bs_crop, max_iter=100, tol=12e-9, tol_stag=1e-2, max_stag=10)

tmr = TMR(As_crop, Bs_crop, verbose=True, device='cuda')
tmr.run_admm(max_iter=150, lr=1e-3, tol=1e-9, rho=0.25)
tmr.print_results()
tmr.show_results()
# Out:
# Iteration:   1 - distance = 4.699e-01 - stopping distance = 8.969e-02
# Iteration:   2 - distance = 4.236e-01 - stopping distance = 4.637e-02
# Iteration:   3 - distance = 3.998e-01 - stopping distance = 2.375e-02
# Iteration:   4 - distance = 3.857e-01 - stopping distance = 1.417e-02
# Iteration:   5 - distance = 3.757e-01 - stopping distance = 9.951e-03
# Iteration:   6 - distance = 3.674e-01 - stopping distance = 8.341e-03
# Iteration:   7 - distance = 3.591e-01 - stopping distance = 8.220e-03
# Iteration:   8 - distance = 3.507e-01 - stopping distance = 8.410e-03
# Iteration:   9 - distance = 3.426e-01 - stopping distance = 8.105e-03
# Iteration:  10 - distance = 3.350e-01 - stopping distance = 7.620e-03
# Iteration:  11 - distance = 3.281e-01 - stopping distance = 6.946e-03
# Iteration:  12 - distance = 3.218e-01 - stopping distance = 6.307e-03
# Iteration:  13 - distance = 3.158e-01 - stopping distance = 5.945e-03
# Iteration:  14 - distance = 3.103e-01 - stopping distance = 5.518e-03
# Iteration:  15 - distance = 3.052e-01 - stopping distance = 5.082e-03
# Iteration:  16 - distance = 3.001e-01 - stopping distance = 5.132e-03
# Iteration:  17 - distance = 2.952e-01 - stopping distance = 4.932e-03
# Iteration:  18 - distance = 2.904e-01 - stopping distance = 4.748e-03
# Iteration:  19 - distance = 2.858e-01 - stopping distance = 4.617e-03
# Iteration:  20 - distance = 2.814e-01 - stopping distance = 4.412e-03
# Iteration:  21 - distance = 2.772e-01 - stopping distance = 4.197e-03
# Iteration:  22 - distance = 2.730e-01 - stopping distance = 4.134e-03
# Iteration:  23 - distance = 2.690e-01 - stopping distance = 4.014e-03
# Iteration:  24 - distance = 2.651e-01 - stopping distance = 3.889e-03
# Iteration:  25 - distance = 2.614e-01 - stopping distance = 3.757e-03
# Iteration:  26 - distance = 2.577e-01 - stopping distance = 3.637e-03
# Iteration:  27 - distance = 2.541e-01 - stopping distance = 3.683e-03
# Iteration:  28 - distance = 2.504e-01 - stopping distance = 3.618e-03
# Iteration:  29 - distance = 2.470e-01 - stopping distance = 3.476e-03
# Iteration:  30 - distance = 2.436e-01 - stopping distance = 3.416e-03
# Iteration:  31 - distance = 2.402e-01 - stopping distance = 3.304e-03
# Iteration:  32 - distance = 2.370e-01 - stopping distance = 3.243e-03
# Iteration:  33 - distance = 2.337e-01 - stopping distance = 3.291e-03
# Iteration:  34 - distance = 2.305e-01 - stopping distance = 3.226e-03
# Iteration:  35 - distance = 2.274e-01 - stopping distance = 3.131e-03
# Iteration:  36 - distance = 2.243e-01 - stopping distance = 3.075e-03
# Iteration:  37 - distance = 2.212e-01 - stopping distance = 3.039e-03
# Iteration:  38 - distance = 2.182e-01 - stopping distance = 3.006e-03
# Iteration:  39 - distance = 2.153e-01 - stopping distance = 2.948e-03
# Iteration:  40 - distance = 2.123e-01 - stopping distance = 2.960e-03
# Iteration:  41 - distance = 2.094e-01 - stopping distance = 2.953e-03
# Iteration:  42 - distance = 2.065e-01 - stopping distance = 2.872e-03
# Iteration:  43 - distance = 2.037e-01 - stopping distance = 2.836e-03
# Iteration:  44 - distance = 2.009e-01 - stopping distance = 2.793e-03
# Iteration:  45 - distance = 1.981e-01 - stopping distance = 2.815e-03
# Iteration:  46 - distance = 1.953e-01 - stopping distance = 2.810e-03
# Iteration:  47 - distance = 1.925e-01 - stopping distance = 2.772e-03
# Iteration:  48 - distance = 1.897e-01 - stopping distance = 2.731e-03
# Iteration:  49 - distance = 1.870e-01 - stopping distance = 2.719e-03
# Iteration:  50 - distance = 1.843e-01 - stopping distance = 2.721e-03
# Iteration:  51 - distance = 1.816e-01 - stopping distance = 2.743e-03
# Iteration:  52 - distance = 1.788e-01 - stopping distance = 2.724e-03
# Iteration:  53 - distance = 1.761e-01 - stopping distance = 2.717e-03
# Iteration:  54 - distance = 1.734e-01 - stopping distance = 2.712e-03
# Iteration:  55 - distance = 1.707e-01 - stopping distance = 2.700e-03
# Iteration:  56 - distance = 1.680e-01 - stopping distance = 2.684e-03
# Iteration:  57 - distance = 1.654e-01 - stopping distance = 2.666e-03
# Iteration:  58 - distance = 1.627e-01 - stopping distance = 2.647e-03
# Iteration:  59 - distance = 1.601e-01 - stopping distance = 2.629e-03
# Iteration:  60 - distance = 1.575e-01 - stopping distance = 2.610e-03
# Iteration:  61 - distance = 1.549e-01 - stopping distance = 2.592e-03
# Iteration:  62 - distance = 1.523e-01 - stopping distance = 2.572e-03
# Iteration:  63 - distance = 1.498e-01 - stopping distance = 2.552e-03
# Iteration:  64 - distance = 1.472e-01 - stopping distance = 2.532e-03
# Iteration:  65 - distance = 1.447e-01 - stopping distance = 2.514e-03
# Iteration:  66 - distance = 1.422e-01 - stopping distance = 2.498e-03
# Iteration:  67 - distance = 1.397e-01 - stopping distance = 2.486e-03
# Iteration:  68 - distance = 1.373e-01 - stopping distance = 2.476e-03
# Iteration:  69 - distance = 1.348e-01 - stopping distance = 2.470e-03
# Iteration:  70 - distance = 1.323e-01 - stopping distance = 2.465e-03
# Iteration:  71 - distance = 1.299e-01 - stopping distance = 2.461e-03
# Iteration:  72 - distance = 1.274e-01 - stopping distance = 2.456e-03
# Iteration:  73 - distance = 1.250e-01 - stopping distance = 2.447e-03
# Iteration:  74 - distance = 1.225e-01 - stopping distance = 2.433e-03
# Iteration:  75 - distance = 1.201e-01 - stopping distance = 2.414e-03
# Iteration:  76 - distance = 1.177e-01 - stopping distance = 2.391e-03
# Iteration:  77 - distance = 1.154e-01 - stopping distance = 2.365e-03
# Iteration:  78 - distance = 1.130e-01 - stopping distance = 2.335e-03
# Iteration:  79 - distance = 1.107e-01 - stopping distance = 2.304e-03
# Iteration:  80 - distance = 1.084e-01 - stopping distance = 2.270e-03
# Iteration:  81 - distance = 1.062e-01 - stopping distance = 2.235e-03
# Iteration:  82 - distance = 1.040e-01 - stopping distance = 2.199e-03
# Iteration:  83 - distance = 1.018e-01 - stopping distance = 2.160e-03
# Iteration:  84 - distance = 9.973e-02 - stopping distance = 2.121e-03
# Iteration:  85 - distance = 9.764e-02 - stopping distance = 2.082e-03
# Iteration:  86 - distance = 9.560e-02 - stopping distance = 2.043e-03
# Iteration:  87 - distance = 9.360e-02 - stopping distance = 2.003e-03
# Iteration:  88 - distance = 9.163e-02 - stopping distance = 1.964e-03
# Iteration:  89 - distance = 8.971e-02 - stopping distance = 1.926e-03
# Iteration:  90 - distance = 8.782e-02 - stopping distance = 1.889e-03
# Iteration:  91 - distance = 8.596e-02 - stopping distance = 1.855e-03
# Iteration:  92 - distance = 8.414e-02 - stopping distance = 1.822e-03
# Iteration:  93 - distance = 8.235e-02 - stopping distance = 1.792e-03
# Iteration:  94 - distance = 8.059e-02 - stopping distance = 1.763e-03
# Iteration:  95 - distance = 7.885e-02 - stopping distance = 1.736e-03
# Iteration:  96 - distance = 7.714e-02 - stopping distance = 1.709e-03
# Iteration:  97 - distance = 7.546e-02 - stopping distance = 1.682e-03
# Iteration:  98 - distance = 7.380e-02 - stopping distance = 1.657e-03
# Iteration:  99 - distance = 7.217e-02 - stopping distance = 1.634e-03
# Iteration: 100 - distance = 7.056e-02 - stopping distance = 1.612e-03
# Iteration: 101 - distance = 6.897e-02 - stopping distance = 1.592e-03
# Iteration: 102 - distance = 6.739e-02 - stopping distance = 1.574e-03
# Iteration: 103 - distance = 6.583e-02 - stopping distance = 1.557e-03
# Iteration: 104 - distance = 6.429e-02 - stopping distance = 1.540e-03
# Iteration: 105 - distance = 6.277e-02 - stopping distance = 1.523e-03
# Iteration: 106 - distance = 6.127e-02 - stopping distance = 1.505e-03
# Iteration: 107 - distance = 5.978e-02 - stopping distance = 1.487e-03
# Iteration: 108 - distance = 5.831e-02 - stopping distance = 1.468e-03
# Iteration: 109 - distance = 5.686e-02 - stopping distance = 1.450e-03
# Iteration: 110 - distance = 5.543e-02 - stopping distance = 1.433e-03
# Iteration: 111 - distance = 5.401e-02 - stopping distance = 1.415e-03
# Iteration: 112 - distance = 5.262e-02 - stopping distance = 1.397e-03
# Iteration: 113 - distance = 5.124e-02 - stopping distance = 1.377e-03
# Iteration: 114 - distance = 4.989e-02 - stopping distance = 1.353e-03
# Iteration: 115 - distance = 4.856e-02 - stopping distance = 1.327e-03
# Iteration: 116 - distance = 4.726e-02 - stopping distance = 1.298e-03
# Iteration: 117 - distance = 4.599e-02 - stopping distance = 1.268e-03
# Iteration: 118 - distance = 4.475e-02 - stopping distance = 1.239e-03
# Iteration: 119 - distance = 4.354e-02 - stopping distance = 1.210e-03
# Iteration: 120 - distance = 4.236e-02 - stopping distance = 1.181e-03
# Iteration: 121 - distance = 4.121e-02 - stopping distance = 1.154e-03
# Iteration: 122 - distance = 4.008e-02 - stopping distance = 1.127e-03
# Iteration: 123 - distance = 3.898e-02 - stopping distance = 1.103e-03
# Iteration: 124 - distance = 3.790e-02 - stopping distance = 1.080e-03
# Iteration: 125 - distance = 3.684e-02 - stopping distance = 1.059e-03
# Iteration: 126 - distance = 3.580e-02 - stopping distance = 1.040e-03
# Iteration: 127 - distance = 3.478e-02 - stopping distance = 1.020e-03
# Iteration: 128 - distance = 3.378e-02 - stopping distance = 1.001e-03
# Iteration: 129 - distance = 3.280e-02 - stopping distance = 9.796e-04
# Iteration: 130 - distance = 3.184e-02 - stopping distance = 9.578e-04
# Iteration: 131 - distance = 3.091e-02 - stopping distance = 9.362e-04
# Iteration: 132 - distance = 2.999e-02 - stopping distance = 9.157e-04
# Iteration: 133 - distance = 2.909e-02 - stopping distance = 8.963e-04
# Iteration: 134 - distance = 2.822e-02 - stopping distance = 8.774e-04
# Iteration: 135 - distance = 2.736e-02 - stopping distance = 8.585e-04
# Iteration: 136 - distance = 2.652e-02 - stopping distance = 8.395e-04
# Iteration: 137 - distance = 2.570e-02 - stopping distance = 8.209e-04
# Iteration: 138 - distance = 2.489e-02 - stopping distance = 8.028e-04
# Iteration: 139 - distance = 2.411e-02 - stopping distance = 7.849e-04
# Iteration: 140 - distance = 2.334e-02 - stopping distance = 7.670e-04
# Iteration: 141 - distance = 2.259e-02 - stopping distance = 7.496e-04
# Iteration: 142 - distance = 2.186e-02 - stopping distance = 7.332e-04
# Iteration: 143 - distance = 2.114e-02 - stopping distance = 7.179e-04
# Iteration: 144 - distance = 2.044e-02 - stopping distance = 7.036e-04
# Iteration: 145 - distance = 1.975e-02 - stopping distance = 6.892e-04
# Iteration: 146 - distance = 1.908e-02 - stopping distance = 6.736e-04
# Iteration: 147 - distance = 1.842e-02 - stopping distance = 6.567e-04
# Iteration: 148 - distance = 1.778e-02 - stopping distance = 6.386e-04
# Iteration: 149 - distance = 1.716e-02 - stopping distance = 6.203e-04
# End MSE: 15.910828464839305
# Best MSE: 15.910828464839305
# End metric: 0.017159861668944162
# Best metric: 0.017159861668944162

# %%
# i = np.random.randint(0, N)
i = 50
A_init = As_crop

Y_model = np.dot(A_init, tmr.X_best)
B_model = np.abs(Y_model)
B_init = Bs_crop

b_init_check = np.reshape(B_init[i,:], (len(idxs),len(idxs)))
b_model_check = np.reshape(B_model[i,:], (len(idxs),len(idxs)))

fig, axs = plt.subplots(1,3, figsize=(12,3))
pl0 = axs[0].imshow(np.square(b_init_check ), cmap="hot")
pl1 = axs[1].imshow(np.square(b_model_check), cmap="hot", vmin=np.min(np.square(b_init_check )), vmax=np.max(np.square(b_init_check )))
pl2 = axs[2].imshow(np.square(b_model_check) - np.square(b_init_check), cmap="RdBu")
plt.colorbar(pl0, ax=axs[0])
plt.colorbar(pl1, ax=axs[1])
plt.colorbar(pl2, ax=axs[2])
axs[0].set_title(r"$B_{init}^2$")
axs[1].set_title(r"$B_{model}^2$")
axs[2].set_title(r"Error: $B_{model}^2 - B_{init}^2$")
[ axs[i].axis('off') for i in range(len(axs)) ]
# Out:
# [(-0.5, 27.5, 27.5, -0.5), (-0.5, 27.5, 27.5, -0.5), (-0.5, 27.5, 27.5, -0.5)]
